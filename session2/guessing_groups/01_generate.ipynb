# %% [markdown]
# # Generating texts
# In this notebook we will generate texts and store them in a CSV file. More precisely, we generate random PhD topics which could potentially be worked on at the UFZ Leipzig structured as described in its [organigram](https://www.ufz.de/export/data/global/98993_organisation-chart_27-10-2025.jpg).

# %%
import bia_bob
import random

# %% [markdown]
# First, we test the connection to the LLM server.

# %%
def prompt_ollama(message:str, model="gemma3:12b", temperature=0.2):
    """A prompt helper function that sends a message to ScaDS.AI LLM server at 
    ZIH TU Dresden and returns only the text response.
    """
    import os
    import openai
    
    # convert message in the right format if necessary
    if isinstance(message, str):
        message = [{"role": "user", "content": message}]
    
    # setup connection to the LLM
    client = openai.OpenAI(base_url="http://localhost:11434/v1",
                           api_key = "none"
            #base_url="https://chat-ai.academiccloud.de/v1",
            #api_key = os.environ.get('KISSKI_API_KEY')
            #base_url="https://llm.scads.ai/v1",
            #api_key=os.environ.get('SCADSAI_API_KEY')
                           # openai/gpt-oss-120b
    )
    response = client.chat.completions.create(
        model=model,
        messages=message,
        temperature=temperature
    )
    
    # extract answer
    return response.choices[0].message.content

prompt_ollama("hello world")
# Out:
# "Hello there! 👋 \n\nIt's great to see you. Is there anything I can help you with today?\n"

# %% [markdown]
# Next, we define a couple of random first and lastnames. We also define a list of institutes.
# These will hint the LLM to generate PhD topics that are relevant to a given institute.

# %%
import pandas as pd
import numpy as np
import random

# Define separate lists for first names and last names
first_names = ["Alex", "Jordan", "Morgan", "Taylor", "Avery",
               "Sam", "Casey", "Riley", "Jamie", "Dakota",
               "Bailey", "Cameron", "Sydney", "Robin", "Charlie",
               "Dana", "Kris", "Skyler", "Devon", "Reese"]

last_names = ["Reed", "Smith", "Lee", "Garcia", "Patel",
              "Chen", "O'Hara", "Jain", "Kumar", "Singh",
              "Liu", "Davis", "Clark", "Thomas", "Brooks",
              "Flores", "Rivera", "Adams", "Gonzalez", "Campbell"]

faculties = """Ecosystems of the Future / Community Ecology
Ecosystems of the Future / Biodiversity and People
Ecosystems of the Future / Ecology of Agroecosystems
Ecosystems of the Future / Soil System Science
Ecosystems of the Future / Computational Landscape Ecology
Ecosystems of the Future / Conservation Biology and Social-Ecological Systems
Ecosystems of the Future / Physiological Diversity
Ecosystems of the Future / Species Interaction Ecology
Water Resources and Environment / Aquatic Ecosystem Analysis
Water Resources and Environment / Catchment Hydrology
Water Resources and Environment / River Ecology
Water Resources and Environment / Hydrogeology
Water Resources and Environment / Lake Research
Chemicals in the Environment / Computational Biology & Chemistry
Chemicals in the Environment / Environmental Analytical Chemistry
Chemicals in the Environment / Exposure Science
Chemicals in the Environment / Molecular Toxicology
Chemicals in the Environment / Ecotoxicology
Chemicals in the Environment / Environmental Immunology
Chemicals in the Environment / Cell Toxicology
Sustainable Ecotechnologies / Applied Microbial Ecology
Sustainable Ecotechnologies / Solar Materials Biotechnology
Sustainable Ecotechnologies / Microbial Biotechnology
Sustainable Ecotechnologies / Molecular Environmental Biotechnology
Sustainable Ecotechnologies / Systemic Environmental Biotechnology
Sustainable Ecotechnologies / Technical Biogeochemistry
Smart Models / Monitoring / Compound Environmental Risks
Smart Models / Monitoring / Computational HydroSystems
Smart Models / Monitoring / Monitoring & Exploration Technologies
Smart Models / Monitoring / Ecological Modelling
Smart Models / Monitoring / Remote Sensing
Smart Models / Monitoring / Environmental Informatics
Environment and Society / System Analysis and Sustainability Assessment
Environment and Society / Economics
Environment and Society / Urban & Environmental Sociology
Environment and Society / Environmental Politics
Environment and Society / Environmental & Planning Law""".split("\n")
len(faculties), faculties[:10]
# Out:
# (37,
#  ['Ecosystems of the Future / Community Ecology',
#   'Ecosystems of the Future / Biodiversity and People',
#   'Ecosystems of the Future / Ecology of Agroecosystems',
#   'Ecosystems of the Future / Soil System Science',
#   'Ecosystems of the Future / Computational Landscape Ecology',
#   'Ecosystems of the Future / Conservation Biology and Social-Ecological Systems',
#   'Ecosystems of the Future / Physiological Diversity',
#   'Ecosystems of the Future / Species Interaction Ecology',
#   'Water Resources and Environment / Aquatic Ecosystem Analysis',
#   'Water Resources and Environment / Catchment Hydrology'])

# %% [markdown]
# In the following loop we select an institute name randomly and ask the LLM server to generate a PhD topic related to the chosen institute.

# %%
research_fields = faculties

# Set random seed for reproducibility
np.random.seed(42)
random.seed(42)

profiles = []

#for field in faculties:
while len(profiles) < 250:    
    # Random name generation from first and last name
    name = f"{random.choice(first_names)} {random.choice(last_names)}"
    field = random.choice(research_fields)

    topic = prompt_ollama(f"""Generate an English PhD thesis topic for someone working at an Environmental Research Center in group '{field}'. Reply with only the title of the research project and nothing else.""", temperature=0.9)
    topic = topic.strip().replace("</s>", "").replace("\"", "")
    if ":" in topic and " " not in topic.split(":")[0]:
        topic = topic.split(":")[1]
    if "</thinking>" in topic:
        topic = topic.split("</thinking>")[1]

    print(len(topic), topic)
    
    profiles.append({
        "name": name,
        "research_field": field,
        "topic": topic
    })
# Out:
# 120 Microplastic-Associated Persistent Organic Pollutants: Bioaccumulation, Trophic Transfer, and Ecological Risk Assessment
# 74 Microbial Community Resilience to Agricultural Runoff in Headwater Streams
# 108 Resilience and Relocation: Social-Ecological Pathways for Coastal Community Adaptation in a Changing Climate
# 114 Resilience and Adaptive Capacity: Integrating Soil Microbiome Dynamics and Crop Diversity in Future Agroecosystems
# 131 Predicting Persistent Organic Pollutant Bioaccumulation and Toxicity Using Integrated Machine Learning and Physiochemical Modeling.
# 140 The Intertwined Futures: Indigenous Ecological Knowledge, Climate Change Adaptation, and Biodiversity Conservation in a Fragmented Landscape
# 129 The Environmental Justice of Urban Heat Islands: A Mixed-Methods Analysis of Vulnerability, Adaptation, and Community Resilience.
# 95 AI-Driven Anomaly Detection in Environmental Sensor Networks: A Bayesian Deep Learning Approach
# 92 Resilience and Regime Shifts in Temperate Forest Ecosystems Under Accelerated Climate Change
# 108 Bio-Inspired Photovoltaics: Integrating Extremophile Metabolic Pathways for Enhanced Solar Energy Conversion
# 113 Computational Modeling of Persistent Organic Pollutant Bioaccumulation and Transformation in Estuarine Ecosystems
# 109 Resilience and Relocation: Social-Ecological Dimensions of Climate-Induced Displacement in Coastal Ecosystems
# 103 Microbial Electrosynthesis for Carbon Capture and Biopolymer Production: A Techno-Ecological Assessment
# 95 Persistent Organic Pollutants and Epigenetic Transgenerational Inheritance in Avian Populations
# 111 The Urban Metabolism of Green Infrastructure: Social Equity and Ecological Resilience in Post-Industrial Cities
# 142 Evaluating Adaptive Capacity: Integrating Indigenous Ecological Knowledge and Predictive Modeling for Coastal Resilience in a Changing Climate
# 119 Microbial Community Shifts and Biofilm Formation in Constructed Wetlands Treating PFAS-Contaminated Industrial Effluent
# 92 Predictive Landscape Modeling of Biodiversity Resilience Under Climate-Induced Regime Shifts
# 101 Immunotoxicological Impacts of Emerging Contaminants on Freshwater Ecosystems: A Multi-Omics Approach
# 96 Physiological Plasticity and Resilience in Plant Communities Facing Anthropogenic Climate Change
# 113 Integrating Machine Learning and Bayesian Networks for Predictive Ecological Modelling Under Environmental Change
# 163 Microbial Community Shifts in Bioaugmented Constructed Wetlands: A Metagenomic and Metatranscriptomic Assessment of Pollutant Degradation and Ecosystem Resilience.
# 144 Microplastic-Associated Persistent Organic Pollutants: Bioavailability, Trophic Transfer, and Ecotoxicological Impacts in Freshwater Ecosystems.
# 108 The Influence of Legacy Pollutants on Riparian Ecosystem Resilience in Agriculturally Modified River Systems
# 81 Microplastic Accumulation and Trophic Transfer in Freshwater Riparian Ecosystems.
# 134 Microplastic-Associated Persistent Organic Pollutants: Bioavailability, Trophic Transfer, and Ecological Risk in Freshwater Ecosystems
# 139 Microbial Community Dynamics in Constructed Wetlands: Assessing Bioaugmentation Strategies for Nutrient Removal and Heavy Metal Remediation
# 109 Resilience and Regime Shifts in Agricultural Ecosystems: Integrating Microbial Ecology and Landscape Dynamics
# 116 Microplastic-Associated Persistent Organic Pollutants: Bioaccumulation and Trophic Transfer in Freshwater Ecosystems
# 92 Legal Personhood and the Rights of Ecosystems: A Comparative Analysis of Emerging Frameworks
# 129 Integrating Machine Learning for Enhanced Predictive Modeling of Ecosystem Response to Climate Change: A Spatiotemporal Analysis.
# 118 The Influence of Land Use Change on Sediment Dynamics and Water Quality in a Managed Catchment: A Multi-Proxy Approach
# 143 Persistent Organic Pollutants as Environmental Justice Indicators: A Spatiotemporal Analysis of Exposure, Vulnerability, and Disparate Impacts.
# 87 Persistent Organic Pollutants and Epigenetic Transgenerational Inheritance in Wildlife.
# 101 Biogeochemical Cycling of Emerging Contaminants in Constructed Wetlands: A Techno-Ecological Approach
# 123 Microplastic Accumulation and Trophic Transfer in Freshwater Wetlands: Implications for Ecosystem Function and Human Health
# 109 Resilience and Relocation: Social-Ecological Dimensions of Climate-Induced Displacement in Coastal Ecosystems
# 98 Hydrological Connectivity and Ecosystem Function in Fragmented Catchments: A Multiscale Assessment
# 133 Predictive Modeling of Ecosystem Resilience Under Accelerated Environmental Change: Integrating Agent-Based Models and Deep Learning.
# 89 Integrating Machine Learning for Enhanced Predictive Accuracy in Dynamic Ecosystem Models
# 76 The Political Ecology of Carbon Sequestration Governance in Coastal Wetlands
# 128 The Environmental Justice of Urban Heat Islands: A Multi-Scalar Analysis of Vulnerability, Resilience, and Adaptation Strategies
# 97 The Cascading Effects of Phenological Mismatch on Trophic Network Stability in a Changing Climate
# 93 The Influence of Legacy Sediment on Riparian Ecosystem Function in Dynamically Managed Rivers
# 95 Persistent Organic Pollutants and Epigenetic Transgenerational Inheritance in Avian Populations
# 102 Assessing the Social-Ecological Resilience of Coastal Communities Facing Climate-Induced Displacement.
# 85 Assessing the Social-Ecological Resilience of Urban Food Systems Under Climate Change
# 73 Hydrological Regime Shifts and Ecosystem Resilience in Managed Catchments
# 95 The Algorithmic Green: Environmental Justice, Predictive Policing, and Urban Forest Management.
# 128 Microbial Community Resilience and Bioremediation Potential in Novel Constructed Wetlands Utilizing Biochar-Enhanced Substrates.
# 97 The Cascading Impacts of Phenological Shifts on Plant-Pollinator Mutualisms in a Changing Climate
# 127 Ubiquitous Flame Retardants: A Critical Discourse Analysis of Scientific Communication, Policy Formation, and Public Perception
# 108 Legal Landscapes: Environmental Justice, Indigenous Sovereignty, and Resource Extraction in the Anthropocene
# 161 Predictive Modeling of Ecosystem Resilience under Compound Climate Stressors: Integrating Remote Sensing, Machine Learning, and Biophysical Process Understanding
# 129 Microbial Community Response to Emerging Contaminants in Urban Stream Ecosystems: Implications for Biomonitoring and Restoration.
# 66 The Political Ecology of Carbon Offset Markets in the Global South
# 77 Valuation of Ecosystem Services in a Context of Climate-Induced Displacement.
# 125 Predictive Modeling of Persistent Organic Pollutant Bioaccumulation and Toxicity Using Multi-Omics Data and Machine Learning.
# 86 Persistent Organic Pollutants and Cellular Stress Response: A Multi-Generational Study
# 120 Spatiotemporal Dynamics of Ecosystem Resilience: Integrating Remote Sensing, Machine Learning, and Agent-Based Modeling.
# 82 The Impacts of Assisted Migration on Trophic Network Stability in Novel Ecosystems
# 89 Predictive Modeling of Ecosystem Resilience Under Climate-Induced Landscape Fragmentation
# 76 The Political Ecology of Carbon Sequestration Governance in Coastal Wetlands
# 128 Persistent Organic Pollutants in Permafrost Thawponds: A Multi-Proxy Approach to Historical Contamination and Ecosystem Response
# 71 Microbial Soil Carbon Dynamics Under Projected Climate Change Scenarios
# 115 Resilience and Adaptive Capacity: Assessing Ecosystem Services in Transitioning Agroecosystems Under Climate Change
# 129 Assessing the Social-Ecological Resilience of Community-Based Natural Resource Management Initiatives: A System Dynamics Approach
# 139 Predictive Modeling of Ecosystem Vulnerability under Climate Change: Integrating Remote Sensing, Machine Learning, and Citizen Science Data
# 123 Microplastic Accumulation and Trophic Transfer in Freshwater Wetlands: Implications for Ecosystem Function and Human Health
# 101 Predictive Modelling of Ecosystem Vulnerability Using Integrated Remote Sensing and Machine Learning.
# 132 Predictive Modeling of Compound Contaminant Effects on Ecosystem Health: Integrating Machine Learning and Ecological Risk Assessment
# 101 Physiological Plasticity and Resilience in Plant Communities Under Simulated Climate Change Scenarios
# 97 Integrating Machine Learning for Predictive Hydrological Modeling and Real-Time Flood Mitigation.
# 91 Microbial Legacy Effects on Soil Carbon Resilience Under Simulated Climate Change Scenarios
# 101 Biochar Amendments and Microbial Community Shifts: A Biogeochemical and Ecosystem Services Assessment
# 104 Persistent Organic Pollutants and Microbiome Disruption: A Multi-Omics Assessment of Exposure and Impact
# 96 Negotiating Resilience: Environmental Justice and Community Knowledge in Urban Flood Adaptation.
# 120 Integrating Machine Learning for Enhanced Flood Forecasting and Uncertainty Quantification in Complex Urban HydroSystems
# 128 Integrating Machine Learning and Agent-Based Modelling to Predict Ecosystem Response to Climate Change and Human Land Use Change
# 85 Algorithmic Bias and Environmental Justice in Spatially Integrated Monitoring Systems
# 88 Microbial Resilience and Soil Carbon Dynamics Under Accelerated Climate Change Scenarios
# 111 Resilience, Relocation, and Reciprocity: Social-Ecological Transitions in Climate-Displaced Coastal Communities
# 92 Predictive Modeling of Compound Contaminant Exposure and Ecological Risk in Urban Watersheds
# 123 Computational Modeling of Persistent Organic Pollutant Bioaccumulation and Transformation in Complex Environmental Matrices
# 114 Hydraulic Connectivity and Biogeochemical Fluxes in Riparian Wetlands: Implications for Riverine Nutrient Dynamics
# 110 Bioaugmentation Strategies for Enhanced Microplastic Degradation in Constructed Wetlands: A Systemic Approach.
# 100 Persistent Organic Pollutants and Immune Dysregulation: A Multi-Generational Immunophenomic Analysis
# 59 Sensor Data Fusion for Enhanced Ecosystem Health Assessment
# 94 The Immunotoxicological Legacy of Persistent Organic Pollutants: A Multi-Generational Analysis
# 114 Negotiating Green Gentrification: Environmental Justice, Community Resilience, and the Production of Urban Nature.
# 89 Microbial Legacy Effects on Soil Carbon Dynamics Under Simulated Climate Change Scenarios
# 99 Quantifying Landscape-Scale Ecosystem Change with Multi-Sensor Remote Sensing and Machine Learning.
# 75 Microbial Community Resilience to Compound Stressors in Urban River Systems
# 129 Resilience and Transformation: Integrating Indigenous Ecological Knowledge and Climate Adaptation Planning in Coastal Ecosystems.
# 87 Predictive Modeling of Ecosystem Resilience Under Combined Climate and Land-Use Change.
# 124 The Cascading Effects of Climate-Induced Phenological Mismatch on Plant-Pollinator Network Structure and Ecosystem Function.
# 123 Resilience and Adaptation of Soil Microbiomes in Intensively Managed Agricultural Landscapes Under Climate Change Scenarios
# 125 Predictive Modeling of Cumulative Environmental Impacts: Integrating Socioeconomic Vulnerability and Compound Risk Assessment
# 80 Valuation of Ecosystem Services and Social Equity in Climate Adaptation Planning
# 135 Predicting and Interpreting Emerging Contaminant Transformation Pathways via Integrated Machine Learning and Quantum Chemical Modeling.
# 87 Persistent Organic Pollutants and Epigenetic Transgenerational Inheritance in Wildlife.
# 76 The Impact of Emerging PFAS on Cellular Stress Response and Ecosystem Health
# 88 Modeling Ecosystem Resilience Under Compound Climate Extremes: A Spatiotemporal Approach
# 125 Legal Personhood and the Rights of Ecosystems: A Comparative Analysis of Emerging Jurisprudence and Implementation Challenges
# 68 The Environmental Justice of Urban Heat Island Mitigation Strategies
# 96 Persistent Organic Pollutants and Epigenetic Transgenerational Inheritance in Avian Populations.
# 109 Predictive Landscape Modeling of Functional Ecosystem Resilience Under Climate Change and Land Use Transition
# 83 The Immunotoxicological Impact of Emerging PFAS on Gut Microbiome-Immune Crosstalk.
# 123 The Environmental Justice of Urban Heat Islands: A Comparative Analysis of Mitigation Strategies and Community Perceptions.
# 88 Valuation of Ecosystem Services Under Climate Change: A Behavioral and Economic Analysis
# 109 Persistent Organic Pollutants and Cellular Stress: An Interdisciplinary Analysis of Combined Exposure Effects
# 93 Persistent Organic Pollutants and Epigenetic Transgenerational Inheritance in *Daphnia magna*
# 102 The Political Ecology of Carbon Sequestration: Narratives, Governance, and Land Rights in the US South
# 140 Emerging Immunotoxicological Impacts of Per- and Polyfluoroalkyl Substances (PFAS) in Freshwater Ecosystems: A Multi-Generational Assessment
# 117 Bio-Integrated Solar Harvesting: A Symbiotic Approach to Photosynthetic Material Design and Environmental Remediation
# 114 Assessing the Social-Ecological Resilience of Coastal Communities Under Climate Change: A System Dynamics Approach
# 89 Microbial Legacy Effects on Soil Carbon Dynamics Under Simulated Climate Change Scenarios
# 112 Microplastic-Associated Persistent Organic Pollutants: Bioavailability, Trophic Transfer, and Ecosystem Impacts.
# 107 Bio-Integrated Solar Cells: A Symbiotic Approach to Sustainable Energy Generation and Ecosystem Restoration
# 129 Microplastic Accumulation and Trophic Transfer in Freshwater Riverine Ecosystems: Implications for Biodiversity and Water Quality
# 112 Integrating Machine Learning and Hydrodynamic Modeling for Predictive Flood Risk Assessment in Urban Watersheds.
# 111 The Cascading Effects of Climate-Driven Phenological Shifts on Plant-Pollinator Networks in Fragmented Habitats
# 95 The Algorithmic Green: Predictive Policing, Environmental Justice, and Urban Forest Management.
# 66 The Political Ecology of Carbon Offset Markets in the Global South
# 111 Microbial Community Shifts and Functional Resilience in Freshwater Wetlands Under Accelerated Nutrient Loading.
# 127 Microbial Electrosynthesis for Bioremediation and Sustainable Resource Recovery: A Molecular and Metabolic Engineering Approach
# 93 Predictive Modeling of Emerging Contaminant Fate and Transport under Climate Change Scenarios
# 120 Microbial Electrosynthesis for Carbon Dioxide Mitigation: Bioelectrochemical System Design and Performance Optimization.
# 168 Assessing the Impact of Agricultural Best Management Practices on Downstream Water Quality and Ecosystem Health: A Spatially Explicit Hydro-Ecological Modeling Approach
# 127 The Impact of Managed Aquifer Recharge on Groundwater Quality and Ecosystem Health: A Hydrogeochemical and Microbial Assessment
# 92 Microbial Tracers as Indicators of Agricultural Contaminant Flow in Fractured Karst Aquifers
# 124 Ubiquitous Flame Retardants: A Multi-Media Exposure Assessment and Neurodevelopmental Implications in Vulnerable Populations
# 93 Physiological Resilience and Adaptive Capacity in Plant Communities Facing Compound Stressors
# 118 Integrating Machine Learning and Satellite Imagery for Predictive Modeling of Coastal Wetland Ecosystem Vulnerability.
# 107 Integrating Machine Learning and Ecological Network Analysis for Predictive Ecosystem Resilience Assessment
# 117 Persistent Organic Pollutants in Sediments: A Multi-Proxy Approach to Historical Contamination and Ecosystem Recovery
# 97 Microbial Community Shifts and Nutrient Cycling in Eutrophic Lakes Under Climate Change Scenarios
# 134 Microplastic-Associated Persistent Organic Pollutants: Bioavailability, Trophic Transfer, and Ecological Risk in Freshwater Ecosystems
# 124 Microbial Electrosynthesis for Carbon Dioxide Remediation and Value-Added Product Generation: A Techno-Ecological Assessment
# 121 The Environmental Justice of Urban Heat Islands: A Comparative Analysis of Community Resilience and Adaptation Strategies
# 117 Shifting Phenologies and Trophic Mismatches: A Network Analysis of Plant-Herbivore Interactions in a Changing Climate
# 103 Persistent Organic Pollutants and Epigenetic Transgenerational Inheritance: A Mechanistic Investigation
# 101 Integrating Machine Learning for Spatiotemporal Hydroecological Forecasting in Complex River Networks
# 118 Predictive Modeling of Compound Flood Risk Under Climate Change: Integrating Machine Learning and HydroSystem Dynamics
# 91 The Cascading Effects of Climate-Driven Phenological Mismatch on Temperate Forest Food Webs
# 112 Phosphorus Cycling Dynamics in Stratified Lakes: Integrating Biogeochemical Processes and Climate Change Impacts
# 116 Predictive Modeling of Nutrient Flux in Estuarine Systems: Integrating Machine Learning and Hydrodynamic Simulations
# 109 The Urban Metabolism of Green Infrastructure: Social Equity and Ecological Function in Post-Industrial Cities
# 117 Predictive Modeling of Hydrological Response to Climate Change Using Hybrid Machine Learning and Process-Based Models
# 110 Microbial Community Shifts and Biogeochemical Function in Constructed Wetlands Treating Industrial Wastewater.
# 114 Assessing the Social-Ecological Resilience of Coastal Communities Under Climate Change: A System Dynamics Approach
# 153 Microbial Biofilms for Heavy Metal Remediation in Constructed Wetlands: A Synergistic Approach Integrating Ecotechnological Design and Microbial Ecology.
# 76 The Political Ecology of Carbon Sequestration Narratives in Coastal Wetlands
# 106 Predictive Modeling of Cumulative Environmental Risk: Integrating Compound Exposure and Ecosystem Response
# 113 Legal Pluralism and Environmental Governance: Indigenous Water Rights and Resource Management in the Anthropocene
# 73 The Political Ecology of Carbon Offset Markets and Indigenous Land Rights
# 78 Immunotoxicological Impacts of Emerging PFAS on Wildlife Reproductive Success.
# 111 Microbial Community Dynamics and Biogeochemical Cycling in Constructed Wetlands Treating Industrial Wastewater.
# 107 Algorithmic Bias in Environmental Sensor Networks: Implications for Ecological Monitoring and Conservation.
# 114 Quantifying Landscape Change and Ecosystem Resilience Using Multi-Source Remote Sensing Data and Machine Learning.
# 77 Immunotoxicological Impacts of Emerging PFAS on Wildlife Reproductive Success
# 131 Bio-Inspired Solar Energy Harvesting: Integrating Photosynthetic Biomimicry and Nanomaterials for Enhanced Efficiency and Stability
# 89 Persistent Organic Pollutants and Cellular Stress Response: A Multi-Generational Analysis
# 99 Hydrological Connectivity and Ecosystem Services in Fragmented Catchments: A Multi-Scale Assessment
# 130 The Bioaccumulation and Transformation of Emerging Flame Retardants in Coastal Ecosystems: A Multi-Compartment Exposure Assessment
# 130 Predictive Ecosystem Modeling: Integrating Deep Learning and Agent-Based Approaches for Resilience Assessment under Climate Change
# 77 Legal Personhood for Ecosystems: Expanding Rights, Redefining Responsibility.
# 159 Predictive Modeling of Ecosystem Resilience Under Dynamic Anthropogenic Stressors: Integrating Remote Sensing, Machine Learning, and Environmental Informatics.
# 117 Quantifying the Influence of Land Management Practices on Sediment Flux and Water Quality in Agricultural Catchments.
# 123 Integrating Machine Learning and Hydrodynamic Modeling to Enhance Flood Risk Prediction and Mitigation in Urban Watersheds.
# 149 Valuation of Ecosystem Services and Community Well-being: A Mixed-Methods Approach to Assessing Nature-Based Solutions in Coastal Resilience Projects
# 90 Environmental Justice and the Political Ecology of Climate Adaptation in Coastal Louisiana
# 133 Integrating Machine Learning for Enhanced Ecological Model Calibration and Uncertainty Quantification in Dynamic Landscape Management
# 147 The Economic Valuation of Nature-Based Solutions for Coastal Resilience: A Comparative Analysis of Community Perceptions and Policy Implementation.
# 114 Microbial Community Shifts and Biogeochemical Functionality in Constructed Wetlands Treating Industrial Effluents.
# 122 Assessing the Nexus of Social-Ecological Resilience, Policy Framing, and Adaptive Governance in Climate-Induced Migration.
# 112 Predictive Modeling of Ecosystem Vulnerability Using Integrated Remote Sensing and Machine Learning Data Streams
# 79 Sensor Networks and Machine Learning for Predictive Ecosystem Health Assessment
# 134 Microplastic-Associated Persistent Organic Pollutants: Bioavailability, Trophic Transfer, and Ecological Risk in Freshwater Ecosystems
# 115 Emerging Contaminants and Cumulative Exposure: A Multi-Omics Analysis of Combined Effects in Vulnerable Populations
# 76 Predictive Modeling of Ecosystem Resilience Under Compound Climate Extremes.
# 111 Persistent Organic Pollutants and Emerging Contaminants: Synergistic Effects on Freshwater Ecosystem Resilience
# 72 Environmental Justice and the Racialized Landscape of Urban Heat Islands
# 97 Hydrological Connectivity and Ecosystem Function in Modified Catchments: A Multi-Scale Assessment
# 99 Hydrological Connectivity and Ecosystem Function in Fragmented Catchments: A Multi-Scale Assessment
# 109 Predictive Modeling of Cumulative Environmental Risk: Integrating Compound Stressors and Ecosystem Resilience
# 111 The Urban Metabolism of Green Infrastructure: Social Equity and Ecological Resilience in Post-Industrial Cities
# 87 Microbial Legacy Effects on Novel Ecosystem Resilience Under Accelerated Climate Change
# 133 Bioaugmentation Strategies for Polycyclic Aromatic Hydrocarbon Degradation in Constructed Wetlands: A Systemic Biotechnology Approach
# 116 Legal Personhood and Ecological Restoration: A Comparative Analysis of Rights, Responsibilities, and Implementation.
# 84 Resilience and Regime Shifts in Fragmented Ecosystems: A Community Ecology Framework
# 114 Bioaugmentation Strategies for Microplastic Degradation in Constructed Wetlands: A Systemic Biotechnology Approach
# 117 The Environmental Justice of Green Infrastructure: A Comparative Analysis of Urban Heat Island Mitigation Strategies.
# 104 Predictive Modeling of Ecosystem Stressors Using Spatiotemporal Environmental Data and Machine Learning.
# 121 Integrating Machine Learning for Enhanced Flood Forecasting and Uncertainty Quantification in Complex Urban HydroSystems.
# 110 Microbial Bioaugmentation for Enhanced Phytoremediation of Heavy Metal-Contaminated Soils: A Systemic Approach
# 103 Microplastic Accumulation and Trophic Transfer in Riverine Food Webs: Implications for Ecosystem Health
# 128 Negotiating Green Gentrification: Environmental Justice, Community Resilience, and Urban Redevelopment in Post-Industrial Cities
# 137 Legal Pluralism and Environmental Governance: Indigenous Knowledge, State Authority, and Resource Management in [Specific Region/Country]
# 131 Predictive Modeling of Hydrological Regime Shifts under Climate Change: Integrating Machine Learning and Process-Based HydroSystems
# 86 Microbial Tracers and Hydrogeological Connectivity in Managed Aquifer Recharge Systems
# 100 Microbial Biofilms for Enhanced Heavy Metal Remediation in Constructed Wetlands: A Systemic Approach
# 85 Predictive Ecological Modelling for Dynamic Ecosystem Resilience Under Climate Change
# 122 Microbial Electrochemical Systems for Valorization of Biochar-Phytoremediation Effluents: A Systemic Life Cycle Assessment
# 123 Emerging Contaminants: A Multi-Omics Assessment of Endocrine Disruption and Neurodevelopmental Effects in Aquatic Wildlife.
# 116 The Intertwined Futures: Assessing the Co-evolution of Human Values and Ecosystem Resilience in a Changing Landscape
# 108 Microbial Bioaugmentation for Enhanced Polycyclic Aromatic Hydrocarbon Degradation in Contaminated Sediments
# 109 Resilience and Regime Shifts in Agricultural Ecosystems: Integrating Microbial Ecology and Landscape Dynamics
# 98 Microbial Community Shifts and Nutrient Cycling in Stratified Lakes Under Climate Change Scenarios
# 97 Hydrological Regime Shifts and Ecosystem Function in Regulated Catchments: A Comparative Analysis
# 132 Integrating Deep Learning and Multi-Source Remote Sensing Data for Enhanced Ecosystem Vulnerability Assessment in a Changing Climate
# 121 Predictive Modeling of Persistent Organic Pollutant Bioaccumulation and Transformation in Complex Environmental Matrices.
# 109 Microbial Community Shifts in Constructed Wetlands: Biogeochemical Consequences and Bioremediation Potential.
# 101 The Role of Microbiome-Mediated Phenological Shifts in Plant-Pollinator Networks Under Climate Change
# 106 Physiological Resilience and Functional Trait Shifts in Plant Communities Under Accelerated Climate Change
# 153 Microbial Transformation Pathways and Toxicogenomic Responses to Emerging Per- and Polyfluoroalkyl Substances (PFAS) in Freshwater Benthic Invertebrates.
# 121 Microbial Carbon Cycling in Restored Coastal Wetlands: Implications for Blue Carbon Sequestration and Climate Mitigation.
# 133 Persistent Organic Pollutants and Cumulative Exposure: A Multi-Omics Approach to Assessing Sublethal Impacts in Freshwater Ecosystems
# 93 Shifting Phenologies and Trophic Mismatches: Cascading Effects in a Changing Arctic Ecosystem
# 112 Microbial Electrochemical Technologies for Polycyclic Aromatic Hydrocarbon Remediation in Contaminated Sediments
# 126 Microbial Communities and Bioaugmentation Strategies for Polycyclic Aromatic Hydrocarbon Degradation in Contaminated Sediments
# 112 Bio-Integrated Solar Harvesting: A Symbiotic Analysis of Microbial Photosynthesis and Bio-Photovoltaic Materials
# 114 Predictive Modeling of Ecosystem Response to Climate Change Using Integrated Sensor Networks and Machine Learning.
# 110 Microbial Community Shifts and Biogeochemical Function in Constructed Wetlands Treating Emerging Contaminants.
# 120 Integrating Machine Learning for Enhanced Flood Forecasting and Uncertainty Quantification in Complex Urban HydroSystems
# 111 Persistent Organic Pollutants and Emerging Contaminants: Synergistic Effects on Freshwater Ecosystem Resilience
# 96 Quantifying Ecosystem Resilience through Integrated Remote Sensing and Machine Learning Analyses
# 109 Persistent Organic Pollutants and Microbiome Disruption: A Multi-Generational Study of Soil Ecosystem Impacts
# 141 Resilience and Transformation: Integrating Indigenous Ecological Knowledge and Climate Adaptation Strategies in Coastal Ecosystem Management.
# 119 Persistent Organic Pollutants and Human Milk: A Multi-Generational Exposure Pathway and Neurodevelopmental Implications
# 112 Bioremediation Potential of Constructed Microbial Ecosystems for Emerging Contaminants in Industrial Wastewater.
# 118 Integrating Machine Learning for Enhanced Predictive Modeling of Urban Heat Island Effects in Data-Sparse Environments
# 107 Integrating Machine Learning for Enhanced Predictive Capacity in Distributed Environmental Sensor Networks.
# 96 Persistent Organic Pollutants and Epigenetic Transgenerational Inheritance in Avian Populations.
# 134 Microplastic-Associated Persistent Organic Pollutants: Bioavailability, Trophic Transfer, and Ecological Risk in Freshwater Ecosystems
# 88 Valuation of Ecosystem Services Under Climate Change: A Behavioral and Economic Analysis
# 112 Ubiquitous Flame Retardants: A Critical Environmental History of Exposure, Policy, and Persistent Contamination.
# 96 Environmental Justice and the Politics of Green Infrastructure in Urban Marginalized Communities
# 126 Integrating Machine Learning for Enhanced Predictive Modeling of Urban Heat Island Effects Using Multi-Source Geospatial Data.
# 132 The Resilience of Social-Ecological Systems: Integrating Indigenous Knowledge and Climate Adaptation Strategies in Coastal Louisiana
# 107 Microbial Mediated Metal Cycling in Constructed Wetlands: A Biogeochemical and Techno-Ecological Assessment
# 110 Microbial Community Shifts and Biogeochemical Function in Constructed Wetlands Treating Emerging Contaminants.
# 82 Valuing Ecosystem Services: Behavioral Economics and Community-Based Conservation.
# 81 Environmental Justice and the Politics of Climate Adaptation in Coastal Louisiana
# 113 Integrating Machine Learning and Bayesian Hierarchical Models for Spatiotemporal Ecosystem Resilience Assessment.
# 96 Persistent Organic Pollutants and Epigenetic Transgenerational Inheritance in Avian Populations.
# 105 Microbial Community Response to Nutrient Loading and Climate Change Impacts in Stratified Lake Ecosystems
# 86 The Urban Metabolism of Green Infrastructure: Social Equity and Ecological Performance
# 108 Predictive Modeling of Persistent Organic Pollutant Bioaccumulation and Transformation Across Trophic Levels
# 120 Valuation of Ecosystem Services and Social Equity: A Mixed-Methods Approach to Payments for Nature in Rural Communities.

# %% [markdown]
# Finally, we store the names, institutes and PhD topics to a csv file.

# %%
# Create DataFrame and save CSV
df = pd.DataFrame(profiles)
df.to_csv("phd_topics.csv", index=False)

df.head()
# Out:
#            name                                     research_field  \
# 0   Taylor Reed       Chemicals in the Environment / Ecotoxicology
# 1    Riley Jain  Water Resources and Environment / Aquatic Ecos...
# 2  Taylor Adams  Ecosystems of the Future / Conservation Biolog...
# 3  Devon Thomas  Ecosystems of the Future / Ecology of Agroecos...
# 4      Alex Lee  Chemicals in the Environment / Computational B...
#
#                                                topic
# 0  Microplastic-Associated Persistent Organic Pol...
# 1  Microbial Community Resilience to Agricultural...
# 2  Resilience and Relocation: Social-Ecological P...
# 3  Resilience and Adaptive Capacity: Integrating ...
# 4  Predicting Persistent Organic Pollutant Bioacc...
